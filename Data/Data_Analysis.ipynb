# %%
# Import the libraries you'll need here.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Load the csv file into a pandas dataframe.
df_old = pd.read_csv('data_old.csv')
df = pd.read_csv('data.csv')
df

#sdf = df.sort_values(['array_type', 'N'], ascending=True)
#sdf
#c1 = df['array_type'] == "sorted"
#sdf = df[c1]
#sdf = sdf[['n', 'type', 'execution_time']]
#sns_plot = sns.lineplot(x='n', y='execution_time', hue='type', data =sdf)
#sns_plot.figure.savefig("sorted_execution_time.png")
# Out:
#          N     n       array_type     k  execution_time  num_of_steps
# 0     5000   100           sorted    69        21443000       6910974
# 1     5000   100         reversed    69        18062300      10308938
# 2     5000   100  random_sequence    69        18347300       8611222
# 3     5000   100        random_50    69        19208688       8611417
# 4     5000   100           sorted    74        20796700       7460218
# ..     ...   ...              ...   ...             ...           ...
# 355  10000  4000        random_50  3345      1640840536     791629803
# 356  10000  4000           sorted  2147       956461200     462053570
# 357  10000  4000         reversed  2147      1042270000     574706962
# 358  10000  4000  random_sequence  2147      1174379200     518406378
# 359  10000  4000        random_50  2147      1088564632     518457583
#
# [360 rows x 6 columns]

# %%
df_old
# Out:
#          N     n       array_type     k      result  execution_time  \
# 0     5000   100           sorted    47    14533900         4706334
# 1     5000   100         reversed    47    14591300         7031442
# 2     5000   100  random_sequence    47    13011400         5867598
# 3     5000   100        random_50    47    13411076         5868074
# 4     5000   100           sorted    27     8711900         2715114
# ..     ...   ...              ...   ...         ...             ...
# 355  10000  4000        random_50   472  8434261254      3995509733
# 356  10000  4000           sorted  2746  1105931000       584765290
# 357  10000  4000         reversed  2746  1182880300       728086322
# 358  10000  4000  random_sequence  2746  1357968700       656413706
# 359  10000  4000        random_50  2746  9792066908      4651995017
#
#      num_of_steps
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 355           NaN
# 356           NaN
# 357           NaN
# 358           NaN
# 359           NaN
#
# [360 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-60f27331e2ef> in <module>
#       6 c2 = df['n'] <= 500
#       7 sdf = df[c1&c2]
# ----> 8 sdf = sdf[['n', 'type', 'execution_time']]
#       9 sns_plot = sns.lineplot(x='n', y='execution_time', hue='type', data =sdf)
#      10 sns_plot.figure.savefig("sorted_execution_time_up_to_500.png")
#
# c:\python38\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# c:\python38\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# c:\python38\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['type'] not in index"

# %%
# Load the csv file into a pandas dataframe.
sns.set()
plt.figure(figsize=(50,25))
#sdf = df.sort_values(['array_type', 'n'], ascending=True)
c1 = df['array_type'] != "random_50"
sdf = df[c1]
#sdf = sdf[['N', 'execution_time']]

# %%
sns.set()
plt.figure(figsize=(50,25))
sns_plot = sns.lineplot(x='N', y='execution_time', hue='array_type', data =sdf)

# %%
sns.set()
plt.figure(figsize=(50,25))
sns_plot = sns.lineplot(x='N', y='num_of_steps', hue='array_type', data =sdf)

# %%
sns.set()
plt.figure(figsize=(50,25))
sns_plot = sns.lineplot(x='N', y='execution_time', hue='array_type', data =df)

# %%
sns.set()
plt.figure(figsize=(50,25))
sns_plot = sns.lineplot(x='N', y='execution_time', hue='array_type', data =df)
sns_plot.figure.savefig("execution_time.png")

# %%
sns.set()
plt.figure(figsize=(50,25))
sns_plot = sns.lineplot(x='N', y='num_of_steps', hue='array_type', data =df)
sns_plot.figure.savefig("num_of_steps.png")

# %%
# Load the csv file into a pandas dataframe.
sns.set()
plt.figure(figsize=(50,25))
#sdf = df.sort_values(['array_type', 'n'], ascending=True)
c1 = df['array_type'] == "random_50"
sdf = df[c1]
sdf = sdf[['n', 'type', 'execution_time']]
sns_plot = sns.lineplot(x='n', y='execution_time', hue='type', data =sdf)
sns_plot.figure.savefig("random_50_execution_time.png")

# %%
# Load the csv file into a pandas dataframe.
sns.set()
plt.figure(figsize=(50,25))
#sdf = df.sort_values(['array_type', 'n'], ascending=True)
c1 = df['array_type'] == "sorted"
sdf = df[c1]
sdf = sdf[['n', 'type', 'num_of_steps']]
sns_plot = sns.lineplot(x='n', y='num_of_steps', hue='type', data =sdf)
sns_plot.figure.savefig("sorted_num_of_steps.png")

# %%
# Load the csv file into a pandas dataframe.
sns.set()
plt.figure(figsize=(50,25))
#sdf = df.sort_values(['array_type', 'n'], ascending=True)
c1 = df['array_type'] == "reversed"
sdf = df[c1]
sdf = sdf[['n', 'type', 'num_of_steps']]
sns_plot = sns.lineplot(x='n', y='num_of_steps', hue='type', data =sdf)
sns_plot.figure.savefig("reversed_num_of_steps.png")

# %%
# Load the csv file into a pandas dataframe.
sns.set()
plt.figure(figsize=(50,25))
#sdf = df.sort_values(['array_type', 'n'], ascending=True)
c1 = df['array_type'] == "random_sequence"
sdf = df[c1]
sdf = sdf[['n', 'type', 'num_of_steps']]
sns_plot = sns.lineplot(x='n', y='num_of_steps', hue='type', data =sdf)
sns_plot.figure.savefig("random_sequence_num_of_steps.png")

# %%
# Load the csv file into a pandas dataframe.
sns.set()
plt.figure(figsize=(50,25))
#sdf = df.sort_values(['array_type', 'n'], ascending=True)
c1 = df['array_type'] == "random_50"
sdf = df[c1]
sdf = sdf[['n', 'type', 'num_of_steps']]
sns_plot = sns.lineplot(x='n', y='num_of_steps', hue='type', data =sdf)
sns_plot.figure.savefig("random_50_num_of_steps.png")
